# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishyansyal/LU2-Dataset-Notebook/blob/main/VKMDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

VKMDataset =  pd.read_csv('/content/drive/MyDrive/Datasets/Uitgebreide_VKM_dataset.csv')
VKMDataset
# Out:
#       id                                               name  \
# 0    159                       Kennismaking met Psychologie
# 1    160                        Learning and working abroad
# 2    161                            Proactieve zorgplanning
# 3    162                                    Rouw en verlies
# 4    163                                Acuut complexe zorg
# ..   ...                                                ...
# 206  393                          Ethiek & kritisch denken
# 207  394                     Avans Innovative Studio Junior
# 208  395                     Avans Innovative Studio Senior
# 209  396                  Succesvol managen van een project
# 210  397  De stem van je geweten. Ga opzoek naar jouw mo...
#
#                                       shortdescription  \
# 0    Brein, gedragsbeinvloeding, ontwikkelingspsych...
# 1    Internationaal, persoonlijke ontwikkeling, ver...
# 2       Proactieve zorgplanning, cocreatie, ziekenhuis
# ...

# %%
VKMDataset.isnull().sum()
# Out:
# id                         0
# name                       0
# shortdescription          20
# description                0
# content                    0
# studycredit                0
# location                   0
# contact_id                 0
# level                      0
# learningoutcomes           5
# Rood                     209
# Groen                    209
# Blauw                    209
# Geel                     209
# module_tags                0
# interests_match_score      0
# popularity_score           0
# estimated_difficulty       0
# available_spots            0
# start_date                 0
# dtype: int64

# %%
VKMDataWithoutNew = VKMDataset.copy()
VKMDataWithoutNew = VKMDataWithoutNew.drop(columns=['content','Rood', 'Groen', 'Blauw','Geel'])
VKMDataWithoutNew['studycredit'] = VKMDataWithoutNew['studycredit'].replace( "Vraag aan de coordinator")
VKMDataWithoutNew
# Out:
# /tmp/ipython-input-1334762166.py:3: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   VKMDataWithoutNew['studycredit'] = VKMDataWithoutNew['studycredit'].replace( "Vraag aan de coordinator")
#       id                                               name  \
# 0    159                       Kennismaking met Psychologie
# 1    160                        Learning and working abroad
# 2    161                            Proactieve zorgplanning
# 3    162                                    Rouw en verlies
# 4    163                                Acuut complexe zorg
# ..   ...                                                ...
# 206  393                          Ethiek & kritisch denken
# 207  394                     Avans Innovative Studio Junior
# 208  395                     Avans Innovative Studio Senior
# ...

# %%
missing_shortdescription_original = VKMDataWithoutNew[VKMDataWithoutNew['shortdescription'].isnull()]
print("Rows in original VKMDataset with missing 'shortdescription':")
missing_shortdescription_original
# Out:
# Rows in original VKMDataset with missing 'shortdescription':
#       id                                               name shortdescription  \
# 60   232                                      Tutorial Club              NaN
# 106  293  Finance for non-financials: Do you want to get...              NaN
# 108  295                      De financial in zijn omgeving              NaN
# 139  326                Operationeel procesadvies (1.3 TBK)              NaN
# 140  327  Analyseren van software en infrastructuur (1.3...              NaN
# 141  328                    Asset characteristics (1.3 IEM)              NaN
# 142  329                Aerospace Engineering & maintenance              NaN
# 143  330                                   Urban innovation              NaN
# 144  331                                Innovatiemanagement              NaN
# 145  332          Software engineering, kwaliteit en testen              NaN
# ...

# %%
VKMDataset.loc[VKMDataset['id'] == 176, 'shortdescription'] = "Your description here"
